# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn.linear_model as LR

# %%
data = pd.read_csv('data/Advertising.csv')

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
#clear linear relationship between TV ad expenditure and sales
plt.scatter(data['TV'], data['sales'], c='black')

# %%
#Generate linear approx. of this data 

X = data['TV'].values.reshape(-1, 1)
Y = data['sales'].values.reshape(-1, 1)

# %%
reg = LR.LinearRegression()
reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = reg.predict(X)

plt.figure(figsize=(16, 8))
plt.scatter(
    data['TV'],
    data['sales'],
    c='black'
)

plt.plot(
    data['TV'],
    predictions,
    c='blue',
    linewidth=2
)

plt.xlabel("Money spent on TV ads ($)")
plt.ylabel("Sales ($)")
plt.show()

# %% [markdown]
# The simple linear regression model can describe the impact of increasing TV ad expenditure on the amount of sales.
